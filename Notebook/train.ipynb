# %%
# %%capture
# !pip install tensorboardX
# !pip install efficientnet_pytorch
# !pip gdown

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Stanford997/CS599-Fake-Video-Detection.git
# Out:
# fatal: destination path 'CS599-Fake-Video-Detection' already exists and is not an empty directory.

# %%
cd CS599-Fake-Video-Detection
# Out:
# /content/CS599-Fake-Video-Detection

# %%
# !git pull https://github.com/Stanford997/CS599-Fake-Video-Detection.git
# Out:
# From https://github.com/Stanford997/CS599-Fake-Video-Detection
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
import os
import shutil
import warnings

import albumentations as A
import numpy as np
import pandas as pd
import torch
import torch.multiprocessing
from torchvision.transforms import ToPILImage, ToTensor

from isplutils import utils, split

torch.multiprocessing.set_sharing_strategy('file_system')
import torch.nn as nn
from albumentations.pytorch import ToTensorV2
from sklearn.metrics import roc_auc_score
from tensorboardX import SummaryWriter
from torch import optim
from torch.utils.data import DataLoader
from tqdm import tqdm
from PIL import ImageChops, Image
from torchvision.models import InceptionOutputs

from architectures import fornet
from isplutils.data import FrameFaceIterableDataset, load_face

# %%
# Neural network type
# net_type = 'Xception'
# net_type = 'EfficientNetB4'
net_type = 'InceptionV3'
net_class = getattr(fornet, net_type)

# %%
# Initialization parameters
train_datasets = ['ff-c23-720-140-140']
val_datasets = ['ff-c23-720-140-140']
ffpp_df_path = '/content/drive/MyDrive/CS599/Dataset/image_df/df.pkl'
ffpp_faces_dir = '/content/drive/MyDrive/CS599/Dataset/image'
dfdc_df_path = None
dfdc_faces_dir = None
face_policy = 'scale'
face_size = 224
if net_type == 'InceptionV3':
    face_size = 299

batch_size = 100
initial_lr = 1e-5
validation_interval = 50
patience = 10
max_num_iterations = 3000
initial_model = None
train_from_scratch = False

max_train_samples = -1
max_val_samples = 6000

log_interval = 30
num_workers = 6
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
seed = 41

debug = False
suffix = None
enable_attention = True

weights_folder = f'weights/{net_type}'
logs_folder = f'logs/{net_type}'

# %%
def tb_attention(tb: SummaryWriter,
                 tag: str,
                 iteration: int,
                 net: nn.Module,
                 device: torch.device,
                 patch_size_load: int,
                 face_crop_scale: str,
                 val_transformer: A.BasicTransform,
                 root: str,
                 record: pd.Series,
                 ):
    # Crop face
    sample_t = load_face(record=record, root=root, size=patch_size_load, scale=face_crop_scale,
                         transformer=val_transformer)
    sample_t_clean = load_face(record=record, root=root, size=patch_size_load, scale=face_crop_scale,
                               transformer=ToTensorV2())
    if torch.cuda.is_available():
        sample_t = sample_t.cuda(device)
    # Transform
    # Feed to net
    with torch.no_grad():
        att: torch.Tensor = net.get_attention(sample_t.unsqueeze(0))[0].cpu()
    att_img: Image.Image = ToPILImage()(att)
    sample_img = ToPILImage()(sample_t_clean)
    att_img = att_img.resize(sample_img.size, resample=Image.NEAREST).convert('RGB')
    sample_att_img = ImageChops.multiply(sample_img, att_img)
    sample_att = ToTensor()(sample_att_img)
    tb.add_image(tag=tag, img_tensor=sample_att, global_step=iteration)


def batch_forward(net: nn.Module, device: torch.device, criterion, data: torch.Tensor, labels: torch.Tensor) -> (
        torch.Tensor, float, int):
    data = data.to(device)
    labels = labels.to(device)
    out = net(data)
    if isinstance(out, InceptionOutputs):
        out = out.logits
    pred = torch.sigmoid(out).detach().cpu().numpy()
    loss = criterion(out, labels)
    return loss, pred


def validation_routine(net, device, val_loader, criterion, tb, iteration, tag: str, loader_len_norm: int = None):
    net.eval()
    loader_len_norm = loader_len_norm if loader_len_norm is not None else val_loader.batch_size
    val_num = 0
    val_loss = 0.
    pred_list = list()
    labels_list = list()
    for val_data in tqdm(val_loader, desc='Validation', leave=False, total=len(val_loader) // loader_len_norm):
        batch_data, batch_labels = val_data

        val_batch_num = len(batch_labels)
        labels_list.append(batch_labels.flatten())
        with torch.no_grad():
            val_batch_loss, val_batch_pred = batch_forward(net, device, criterion, batch_data,
                                                           batch_labels)
        pred_list.append(val_batch_pred.flatten())
        val_num += val_batch_num
        val_loss += val_batch_loss.item() * val_batch_num

    # Logging
    val_loss /= val_num
    tb.add_scalar('{}/loss'.format(tag), val_loss, iteration)

    if isinstance(criterion, nn.BCEWithLogitsLoss):
        val_labels = np.concatenate(labels_list)
        val_pred = np.concatenate(pred_list)
        val_roc_auc = roc_auc_score(val_labels, val_pred)
        tb.add_scalar('{}/roc_auc'.format(tag), val_roc_auc, iteration)
        tb.add_pr_curve('{}/pr'.format(tag), val_labels, val_pred, iteration)

    return val_loss


def save_model(net: nn.Module, optimizer: optim.Optimizer,
               train_loss: float, val_loss: float,
               iteration: int, batch_size: int, epoch: int,
               path: str):
    path = str(path)
    state = dict(net=net.state_dict(),
                 opt=optimizer.state_dict(),
                 train_loss=train_loss,
                 val_loss=val_loss,
                 iteration=iteration,
                 batch_size=batch_size,
                 epoch=epoch)
    torch.save(state, path)

# %%
# Random initialization
np.random.seed(seed)
torch.random.manual_seed(seed)

# Load net
net: nn.Module = net_class().to(device)

# Loss and optimizers
criterion = nn.BCEWithLogitsLoss()

min_lr = initial_lr * 1e-5
optimizer = optim.Adam(net.get_trainable_parameters(), lr=initial_lr)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer=optimizer,
    mode='min',
    factor=0.1,
    patience=patience,
    cooldown=2 * patience,
    min_lr=min_lr,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
tag = utils.make_train_tag(net_class=net_class,
                           traindb=train_datasets,
                           face_policy=face_policy,
                           patch_size=face_size,
                           seed=seed,
                           suffix=suffix,
                           debug=debug,
                           )

# Model checkpoint paths
bestval_path = os.path.join(weights_folder, tag, 'bestval.pth')
last_path = os.path.join(weights_folder, tag, 'last.pth')
periodic_path = os.path.join(weights_folder, tag, 'it{:06d}.pth')

os.makedirs(os.path.join(weights_folder, tag), exist_ok=True)

# Load model
val_loss = min_val_loss = 10
epoch = iteration = 0
net_state = None
opt_state = None
if initial_model is not None:
    # If given load initial model
    print('Loading model form: {}'.format(initial_model))
    state = torch.load(initial_model, map_location='cpu')
    net_state = state['net']
elif not train_from_scratch and os.path.exists(last_path):
    print('Loading model form: {}'.format(last_path))
    state = torch.load(last_path, map_location='cpu')
    net_state = state['net']
    opt_state = state['opt']
    iteration = state['iteration'] + 1
    epoch = state['epoch']
if not train_from_scratch and os.path.exists(bestval_path):
    state = torch.load(bestval_path, map_location='cpu')
    min_val_loss = state['val_loss']
if net_state is not None:
    incomp_keys = net.load_state_dict(net_state, strict=False)
    print(incomp_keys)
if opt_state is not None:
    for param_group in opt_state['param_groups']:
        param_group['lr'] = initial_lr
    optimizer.load_state_dict(opt_state)

# Initialize Tensorboard
logdir = os.path.join(logs_folder, tag)
if iteration == 0:
    # If training from scratch or initialization remove history if exists
    shutil.rmtree(logdir, ignore_errors=True)

# TensorboardX instance
tb = SummaryWriter(logdir=logdir)
if iteration == 0:
    dummy = torch.randn((1, 3, face_size, face_size), device=device)
    dummy = dummy.to(device)
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        tb.add_graph(net, [dummy, ], verbose=False)

transformer = utils.get_transformer(face_policy=face_policy, patch_size=face_size,
                                    net_normalizer=net.get_normalizer(), train=True)

# Datasets and data loaders
print('Loading data')
# Check if paths for DFDC and FF++ extracted faces and DataFrames are provided
for dataset in train_datasets:
    if dataset.split('-')[0] == 'dfdc' and (dfdc_df_path is None or dfdc_faces_dir is None):
        raise RuntimeError('Specify DataFrame and directory for DFDC faces for training!')
    elif dataset.split('-')[0] == 'ff' and (ffpp_df_path is None or ffpp_faces_dir is None):
        raise RuntimeError('Specify DataFrame and directory for FF++ faces for training!')
for dataset in val_datasets:
    if dataset.split('-')[0] == 'dfdc' and (dfdc_df_path is None or dfdc_faces_dir is None):
        raise RuntimeError('Specify DataFrame and directory for DFDC faces for validation!')
    elif dataset.split('-')[0] == 'ff' and (ffpp_df_path is None or ffpp_faces_dir is None):
        raise RuntimeError('Specify DataFrame and directory for FF++ faces for validation!')
# Load splits with the make_splits function
splits = split.make_splits(dfdc_df=dfdc_df_path, ffpp_df=ffpp_df_path, dfdc_dir=dfdc_faces_dir, ffpp_dir=ffpp_faces_dir,
                           dbs={'train': train_datasets, 'val': val_datasets})
train_dfs = [splits['train'][db][0] for db in splits['train']]
train_roots = [splits['train'][db][1] for db in splits['train']]
val_roots = [splits['val'][db][1] for db in splits['val']]
val_dfs = [splits['val'][db][0] for db in splits['val']]
# Out:
# Parameters
# {'face': 'scale',
#  'net': 'InceptionV3',
#  'seed': 41,
#  'size': 299,
#  'traindb': 'ff-c23-720-140-140'}
# Tag: net-InceptionV3_traindb-ff-c23-720-140-140_face-scale_size-299_seed-41
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1692: UserWarning: Using default interpolation INTER_NEAREST, which is sub-optimal.Please specify interpolation mode for downscale and upscale explicitly.For additional information see this PR https://github.com/albumentations-team/albumentations/pull/584
#   warnings.warn(
# Loading data

# %%
train_dataset = FrameFaceIterableDataset(roots=train_roots,
                                         dfs=train_dfs,
                                         scale=face_policy,
                                         num_samples=max_train_samples,
                                         transformer=transformer,
                                         size=face_size,
                                         )

val_dataset = FrameFaceIterableDataset(roots=val_roots,
                                       dfs=val_dfs,
                                       scale=face_policy,
                                       num_samples=max_val_samples,
                                       transformer=transformer,
                                       size=face_size,
                                       )

train_loader = DataLoader(train_dataset, num_workers=num_workers, batch_size=batch_size, )
val_loader = DataLoader(val_dataset, num_workers=num_workers, batch_size=batch_size, )

print('Training samples: {}'.format(len(train_dataset)))
print('Validation samples: {}'.format(len(val_dataset)))
# Out:
# Training samples: 51528
# Validation samples: 6000
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
stop = False
while not stop:

    # Training
    optimizer.zero_grad()

    train_loss = train_num = 0
    train_pred_list = []
    train_labels_list = []
    for train_batch in tqdm(train_loader, desc='Epoch {:03d}'.format(epoch), leave=False,
                            total=len(train_loader) // train_loader.batch_size):
        net.train()
        batch_data, batch_labels = train_batch

        train_batch_num = len(batch_labels)
        train_num += train_batch_num
        train_labels_list.append(batch_labels.numpy().flatten())

        train_batch_loss, train_batch_pred = batch_forward(net, device, criterion, batch_data, batch_labels)
        train_pred_list.append(train_batch_pred.flatten())

        if torch.isnan(train_batch_loss):
            raise ValueError('NaN loss')

        train_loss += train_batch_loss.item() * train_batch_num

        # Optimization
        train_batch_loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # Logging
        if iteration > 0 and (iteration % log_interval == 0):
            train_loss /= train_num
            tb.add_scalar('train/loss', train_loss, iteration)
            tb.add_scalar('lr', optimizer.param_groups[0]['lr'], iteration)
            tb.add_scalar('epoch', epoch, iteration)

            # Checkpoint
            save_model(net, optimizer, train_loss, val_loss, iteration, batch_size, epoch, last_path)
            train_loss = train_num = 0

        # Validation
        if iteration > 0 and (iteration % validation_interval == 0):

            # Model checkpoint
            save_model(net, optimizer, train_loss, val_loss, iteration, batch_size, epoch,
                       periodic_path.format(iteration))

            # Train cumulative stats
            train_labels = np.concatenate(train_labels_list)
            train_pred = np.concatenate(train_pred_list)
            train_labels_list = []
            train_pred_list = []

            train_roc_auc = roc_auc_score(train_labels, train_pred)
            tb.add_scalar('train/roc_auc', train_roc_auc, iteration)
            tb.add_pr_curve('train/pr', train_labels, train_pred, iteration)

            # Validation
            val_loss = validation_routine(net, device, val_loader, criterion, tb, iteration, 'val')
            tb.flush()

            # LR Scheduler
            lr_scheduler.step(val_loss)

            # Model checkpoint
            if val_loss < min_val_loss:
                min_val_loss = val_loss
                save_model(net, optimizer, train_loss, val_loss, iteration, batch_size, epoch, bestval_path)

            # Attention
            if enable_attention and hasattr(net, 'get_attention'):
                net.eval()
                # For each dataframe show the attention for a real,fake couple of frames
                for df, root, sample_idx, tag in [
                    (train_dfs[0], train_roots[0], train_dfs[0][train_dfs[0]['label'] == False].index[0],
                     'train/att/real'),
                    (train_dfs[0], train_roots[0], train_dfs[0][train_dfs[0]['label'] == True].index[0],
                     'train/att/fake'),
                ]:
                    record = df.loc[sample_idx]
                    tb_attention(tb, tag, iteration, net, device, face_size, face_policy,
                                 transformer, root, record)

            if optimizer.param_groups[0]['lr'] == min_lr:
                print('Reached minimum learning rate. Stopping.')
                stop = True
                break

        iteration += 1

        if iteration > max_num_iterations:
            print('Maximum number of iterations reached')
            stop = True
            break

        # End of iteration

    epoch += 1

# Needed to flush out last events
tb.close()

print('Completed')
# Out:
# Epoch 000:   0%|          | 0/3 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 000: 64it [04:08,  3.51s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:35, 35.12s/it]
# Validation: 2it [00:35, 14.96s/it]
# Validation: 3it [00:36,  8.40s/it]
# Validation: 4it [00:37,  5.33s/it]
# Validation: 5it [00:37,  3.61s/it]
# Validation: 6it [00:38,  2.57s/it]
# Validation: 7it [00:56,  7.63s/it]
# Validation: 8it [00:56,  5.37s/it]
# Validation: 9it [00:57,  3.87s/it]
# Validation: 10it [00:57,  2.83s/it]
# Validation: 11it [00:58,  2.15s/it]
# Validation: 12it [00:59,  1.67s/it]
# Validation: 13it [01:14,  5.71s/it]
# Validation: 14it [01:15,  4.43s/it]
# Validation: 15it [01:16,  3.33s/it]
# Validation: 16it [01:17,  2.57s/it]
# Validation: 17it [01:17,  2.01s/it]
# Validation: 18it [01:18,  1.62s/it]
# Validation: 19it [01:33,  5.63s/it]
# Validation: 20it [01:34,  4.19s/it]
# Validation: 21it [01:35,  3.14s/it]
# Validation: 22it [01:35,  2.38s/it]
# Validation: 23it [01:36,  1.86s/it]
# Validation: 24it [01:36,  1.47s/it]
# Validation: 25it [01:51,  5.34s/it]
# Validation: 26it [01:52,  3.97s/it]
# Validation: 27it [01:52,  2.96s/it]
# Validation: 28it [01:53,  2.24s/it]
# Validation: 29it [01:53,  1.76s/it]
# Validation: 30it [01:54,  1.41s/it]
# Validation: 31it [02:10,  5.71s/it]
# Validation: 32it [02:11,  4.27s/it]
# Validation: 33it [02:12,  3.29s/it]
# Validation: 34it [02:13,  2.85s/it]
# Validation: 35it [02:14,  2.28s/it]
# Validation: 36it [02:15,  1.84s/it]
# Validation: 37it [02:29,  5.54s/it]
# Validation: 38it [02:31,  4.23s/it]
# Validation: 39it [02:31,  3.19s/it]
# Validation: 40it [02:34,  2.93s/it]
# Validation: 41it [02:34,  2.26s/it]
# Validation: 42it [02:35,  1.74s/it]
# Validation: 43it [02:44,  3.87s/it]
# Validation: 44it [02:45,  3.23s/it]
# Validation: 45it [02:46,  2.39s/it]
# Validation: 46it [02:47,  1.90s/it]
# Validation: 47it [02:47,  1.47s/it]
# Validation: 48it [02:48,  1.16s/it]
# Epoch 000: 128it [10:14,  3.55s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:20, 20.25s/it]
# Validation: 2it [00:21,  8.80s/it]
# Validation: 3it [00:22,  5.27s/it]
# Validation: 4it [00:23,  3.58s/it]
# Validation: 5it [00:24,  2.68s/it]
# Validation: 6it [00:25,  2.25s/it]
# Validation: 7it [00:38,  5.72s/it]
# Validation: 8it [00:39,  4.21s/it]
# Validation: 9it [00:40,  3.26s/it]
# Validation: 10it [00:41,  2.66s/it]
# Validation: 11it [00:43,  2.20s/it]
# Validation: 12it [00:43,  1.80s/it]
# Validation: 13it [00:56,  4.98s/it]
# Validation: 14it [00:57,  3.84s/it]
# Validation: 15it [00:58,  2.97s/it]
# Validation: 16it [00:59,  2.40s/it]
# Validation: 17it [01:00,  1.95s/it]
# Validation: 18it [01:00,  1.54s/it]
# Validation: 19it [01:10,  4.08s/it]
# Validation: 20it [01:11,  3.07s/it]
# Validation: 21it [01:12,  2.49s/it]
# Validation: 22it [01:14,  2.09s/it]
# Validation: 23it [01:14,  1.76s/it]
# Validation: 24it [01:15,  1.48s/it]
# Validation: 25it [01:25,  3.80s/it]
# Validation: 26it [01:26,  3.00s/it]
# Validation: 27it [01:27,  2.46s/it]
# Validation: 28it [01:28,  2.05s/it]
# Validation: 29it [01:29,  1.77s/it]
# Validation: 30it [01:30,  1.49s/it]
# Validation: 31it [01:38,  3.57s/it]
# Validation: 32it [01:39,  2.76s/it]
# Validation: 33it [01:40,  2.25s/it]
# Validation: 34it [01:41,  1.91s/it]
# Validation: 35it [01:43,  1.69s/it]
# Validation: 36it [01:44,  1.51s/it]
# Validation: 37it [01:52,  3.49s/it]
# Validation: 38it [01:52,  2.66s/it]
# Validation: 39it [01:53,  2.11s/it]
# Validation: 40it [01:54,  1.73s/it]
# Validation: 41it [01:55,  1.50s/it]
# Validation: 42it [01:56,  1.38s/it]
# Validation: 43it [02:02,  2.70s/it]
# Validation: 44it [02:02,  2.02s/it]
# Validation: 45it [02:03,  1.54s/it]
# Validation: 46it [02:03,  1.21s/it]
# Validation: 47it [02:04,  1.02it/s]
# Validation: 48it [02:04,  1.23it/s]
# Epoch 000: 192it [15:42,  3.46s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:21, 21.72s/it]
# Validation: 2it [00:23,  9.76s/it]
# Validation: 3it [00:24,  5.84s/it]
# Validation: 4it [00:25,  4.13s/it]
# Validation: 5it [00:26,  3.06s/it]
# Validation: 6it [00:27,  2.28s/it]
# Validation: 7it [00:43,  6.55s/it]
# Validation: 8it [00:43,  4.75s/it]
# Validation: 9it [00:44,  3.53s/it]
# Validation: 10it [00:45,  2.71s/it]
# Validation: 11it [00:46,  2.15s/it]
# Validation: 12it [00:47,  1.73s/it]
# Validation: 13it [00:59,  5.01s/it]
# Validation: 14it [01:00,  3.75s/it]
# Validation: 15it [01:01,  2.90s/it]
# Validation: 16it [01:02,  2.30s/it]
# Validation: 17it [01:03,  1.86s/it]
# Validation: 18it [01:04,  1.53s/it]
# Validation: 19it [01:18,  5.52s/it]
# Validation: 20it [01:20,  4.20s/it]
# Validation: 21it [01:21,  3.32s/it]
# Validation: 22it [01:22,  2.67s/it]
# Validation: 23it [01:23,  2.25s/it]
# Validation: 24it [01:24,  1.92s/it]
# Validation: 25it [01:35,  4.40s/it]
# Validation: 26it [01:35,  3.34s/it]
# Validation: 27it [01:36,  2.60s/it]
# Validation: 28it [01:37,  2.08s/it]
# Validation: 29it [01:38,  1.69s/it]
# Validation: 30it [01:39,  1.43s/it]
# Validation: 31it [01:49,  4.08s/it]
# Validation: 32it [01:50,  3.09s/it]
# Validation: 33it [01:51,  2.43s/it]
# Validation: 34it [01:52,  1.99s/it]
# Validation: 35it [01:53,  1.64s/it]
# Validation: 36it [01:53,  1.36s/it]
# Validation: 37it [02:03,  3.85s/it]
# Validation: 38it [02:04,  2.93s/it]
# Validation: 39it [02:05,  2.31s/it]
# Validation: 40it [02:06,  1.90s/it]
# Validation: 41it [02:06,  1.61s/it]
# Validation: 42it [02:07,  1.37s/it]
# Validation: 43it [02:12,  2.33s/it]
# Validation: 44it [02:12,  1.79s/it]
# Validation: 45it [02:13,  1.41s/it]
# Validation: 46it [02:13,  1.15s/it]
# Validation: 47it [02:14,  1.06it/s]
# Validation: 48it [02:14,  1.25it/s]
# Epoch 000: 256it [21:17,  3.25s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:21, 21.95s/it]
# Validation: 2it [00:22,  9.44s/it]
# Validation: 3it [00:23,  5.58s/it]
# Validation: 4it [00:24,  3.81s/it]
# Validation: 5it [00:25,  2.80s/it]
# Validation: 6it [00:26,  2.13s/it]
# Validation: 7it [00:40,  6.12s/it]
# Validation: 8it [00:41,  4.45s/it]
# Validation: 9it [00:42,  3.34s/it]
# Validation: 10it [00:43,  2.63s/it]
# Validation: 11it [00:44,  2.18s/it]
# Validation: 12it [00:46,  1.88s/it]
# Validation: 13it [00:59,  5.38s/it]
# Validation: 14it [01:00,  4.08s/it]
# Validation: 15it [01:01,  3.15s/it]
# Validation: 16it [01:02,  2.53s/it]
# Validation: 17it [01:03,  2.00s/it]
# Validation: 18it [01:04,  1.62s/it]
# Validation: 19it [01:13,  3.81s/it]
# Validation: 20it [01:14,  2.98s/it]
# Validation: 21it [01:15,  2.43s/it]
# Validation: 22it [01:16,  1.96s/it]
# Validation: 23it [01:17,  1.66s/it]
# Validation: 24it [01:18,  1.45s/it]
# Validation: 25it [01:27,  3.72s/it]
# Validation: 26it [01:27,  2.85s/it]
# Validation: 27it [01:28,  2.32s/it]
# Validation: 28it [01:30,  1.95s/it]
# Validation: 29it [01:31,  1.70s/it]
# Validation: 30it [01:32,  1.46s/it]
# Validation: 31it [01:40,  3.56s/it]
# Validation: 32it [01:41,  2.75s/it]
# Validation: 33it [01:42,  2.15s/it]
# Validation: 34it [01:43,  1.77s/it]
# Validation: 35it [01:44,  1.54s/it]
# Validation: 36it [01:45,  1.39s/it]
# Validation: 37it [01:54,  3.91s/it]
# Validation: 38it [01:55,  2.97s/it]
# Validation: 39it [01:56,  2.33s/it]
# Validation: 40it [01:57,  1.87s/it]
# Validation: 41it [01:58,  1.53s/it]
# Validation: 42it [01:59,  1.43s/it]
# Validation: 43it [02:05,  2.84s/it]
# Validation: 44it [02:05,  2.11s/it]
# Validation: 45it [02:06,  1.60s/it]
# Validation: 46it [02:06,  1.25s/it]
# Validation: 47it [02:07,  1.01s/it]
# Validation: 48it [02:07,  1.20it/s]
# Epoch 000: 320it [26:43,  3.06s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:21, 21.28s/it]
# Validation: 2it [00:22,  9.36s/it]
# Validation: 3it [00:23,  5.51s/it]
# Validation: 4it [00:24,  3.67s/it]
# Validation: 5it [00:24,  2.68s/it]
# Validation: 6it [00:25,  2.06s/it]
# Validation: 7it [00:38,  5.67s/it]
# Validation: 8it [00:39,  4.15s/it]
# Validation: 9it [00:40,  3.13s/it]
# Validation: 10it [00:41,  2.45s/it]
# Validation: 11it [00:42,  1.97s/it]
# Validation: 12it [00:43,  1.59s/it]
# Validation: 13it [00:55,  4.87s/it]
# Validation: 14it [00:56,  3.69s/it]
# Validation: 15it [00:57,  2.82s/it]
# Validation: 16it [00:58,  2.24s/it]
# Validation: 17it [00:59,  1.86s/it]
# Validation: 18it [01:00,  1.66s/it]
# Validation: 19it [01:11,  4.31s/it]
# Validation: 20it [01:11,  3.24s/it]
# Validation: 21it [01:12,  2.56s/it]
# Validation: 22it [01:13,  2.04s/it]
# Validation: 23it [01:14,  1.71s/it]
# Validation: 24it [01:15,  1.52s/it]
# Validation: 25it [01:25,  3.93s/it]
# Validation: 26it [01:25,  3.01s/it]
# Validation: 27it [01:26,  2.35s/it]
# Validation: 28it [01:27,  1.90s/it]
# Validation: 29it [01:28,  1.59s/it]
# Validation: 30it [01:29,  1.41s/it]
# Validation: 31it [01:38,  3.83s/it]
# Validation: 32it [01:39,  2.95s/it]
# Validation: 33it [01:40,  2.32s/it]
# Validation: 34it [01:41,  1.87s/it]
# Validation: 35it [01:42,  1.54s/it]
# Validation: 36it [01:43,  1.33s/it]
# Validation: 37it [01:52,  3.81s/it]
# Validation: 38it [01:53,  2.91s/it]
# Validation: 39it [01:54,  2.25s/it]
# Validation: 40it [01:55,  1.82s/it]
# Validation: 41it [01:55,  1.49s/it]
# Validation: 42it [01:56,  1.28s/it]
# Validation: 43it [02:03,  2.91s/it]
# Validation: 44it [02:03,  2.17s/it]
# Validation: 45it [02:04,  1.64s/it]
# Validation: 46it [02:04,  1.28s/it]
# Validation: 47it [02:04,  1.02s/it]
# Validation: 48it [02:05,  1.19it/s]
# Epoch 000: 384it [32:19,  3.32s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:21, 21.57s/it]
# Validation: 2it [00:22,  9.66s/it]
# Validation: 3it [00:24,  5.89s/it]
# Validation: 4it [00:25,  4.07s/it]
# Validation: 5it [00:26,  3.10s/it]
# Validation: 6it [00:28,  2.44s/it]
# Validation: 7it [00:40,  5.67s/it]
# Validation: 8it [00:41,  4.25s/it]
# Validation: 9it [00:42,  3.32s/it]
# Validation: 10it [00:43,  2.57s/it]
# Validation: 11it [00:44,  2.02s/it]
# Validation: 12it [00:45,  1.66s/it]
# Validation: 13it [00:57,  4.89s/it]
# Validation: 14it [00:58,  3.70s/it]
# Validation: 15it [00:59,  2.86s/it]
# Validation: 16it [01:00,  2.26s/it]
# Validation: 17it [01:01,  1.84s/it]
# Validation: 18it [01:02,  1.55s/it]
# Validation: 19it [01:11,  3.99s/it]
# Validation: 20it [01:12,  3.11s/it]
# Validation: 21it [01:13,  2.43s/it]
# Validation: 22it [01:14,  1.96s/it]
# Validation: 23it [01:15,  1.60s/it]
# Validation: 24it [01:16,  1.38s/it]
# Validation: 25it [01:25,  3.77s/it]
# Validation: 26it [01:26,  3.00s/it]
# Validation: 27it [01:27,  2.42s/it]
# Validation: 28it [01:29,  2.03s/it]
# Validation: 29it [01:29,  1.65s/it]
# Validation: 30it [01:30,  1.43s/it]
# Validation: 31it [01:40,  3.81s/it]
# Validation: 32it [01:41,  3.01s/it]
# Validation: 33it [01:42,  2.41s/it]
# Validation: 34it [01:43,  2.01s/it]
# Validation: 35it [01:44,  1.70s/it]
# Validation: 36it [01:45,  1.42s/it]
# Validation: 37it [01:54,  3.72s/it]
# Validation: 38it [01:55,  2.93s/it]
# Validation: 39it [01:56,  2.38s/it]
# Validation: 40it [01:57,  2.01s/it]
# Validation: 41it [01:58,  1.69s/it]
# Validation: 42it [01:59,  1.49s/it]
# Validation: 43it [02:05,  2.87s/it]
# Validation: 44it [02:05,  2.13s/it]
# Validation: 45it [02:06,  1.63s/it]
# Validation: 46it [02:06,  1.26s/it]
# Validation: 47it [02:07,  1.02s/it]
# Validation: 48it [02:07,  1.18it/s]
# Epoch 001:   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 001: 40it [02:01,  2.52s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:26, 26.67s/it]
# Validation: 2it [00:27, 11.62s/it]
# Validation: 3it [00:28,  6.75s/it]
# Validation: 4it [00:29,  4.36s/it]
# Validation: 5it [00:30,  3.06s/it]
# Validation: 6it [00:30,  2.30s/it]
# Validation: 7it [00:41,  4.99s/it]
# Validation: 8it [00:42,  3.72s/it]
# Validation: 9it [00:43,  2.86s/it]
# Validation: 10it [00:44,  2.23s/it]
# Validation: 11it [00:45,  1.80s/it]
# Validation: 12it [00:45,  1.49s/it]
# Validation: 13it [00:54,  3.73s/it]
# Validation: 14it [00:55,  2.96s/it]
# Validation: 15it [00:57,  2.39s/it]
# Validation: 16it [00:58,  2.02s/it]
# Validation: 17it [00:59,  1.66s/it]
# Validation: 18it [00:59,  1.40s/it]
# Validation: 19it [01:08,  3.63s/it]
# Validation: 20it [01:09,  2.89s/it]
# Validation: 21it [01:10,  2.30s/it]
# Validation: 22it [01:11,  1.96s/it]
# Validation: 23it [01:12,  1.66s/it]
# Validation: 24it [01:13,  1.48s/it]
# Validation: 25it [01:23,  3.89s/it]
# Validation: 26it [01:24,  3.03s/it]
# Validation: 27it [01:25,  2.47s/it]
# Validation: 28it [01:26,  2.05s/it]
# Validation: 29it [01:27,  1.78s/it]
# Validation: 30it [01:28,  1.51s/it]
# Validation: 31it [01:36,  3.50s/it]
# Validation: 32it [01:37,  2.71s/it]
# Validation: 33it [01:38,  2.16s/it]
# Validation: 34it [01:39,  1.78s/it]
# Validation: 35it [01:40,  1.62s/it]
# Validation: 36it [01:41,  1.49s/it]
# Validation: 37it [01:51,  4.00s/it]
# Validation: 38it [01:52,  3.03s/it]
# Validation: 39it [01:53,  2.37s/it]
# Validation: 40it [01:54,  1.94s/it]
# Validation: 41it [01:55,  1.72s/it]
# Validation: 42it [01:56,  1.51s/it]
# Validation: 43it [02:02,  2.95s/it]
# Validation: 44it [02:03,  2.22s/it]
# Validation: 45it [02:03,  1.68s/it]
# Validation: 46it [02:04,  1.33s/it]
# Validation: 47it [02:04,  1.06s/it]
# Validation: 48it [02:05,  1.15it/s]
# Epoch 001: 104it [06:35,  2.35s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:28, 28.60s/it]
# Validation: 2it [00:30, 12.62s/it]
# Validation: 3it [00:30,  7.24s/it]
# Validation: 4it [00:31,  4.82s/it]
# Validation: 5it [00:33,  3.46s/it]
# Validation: 6it [00:34,  2.69s/it]
# Validation: 7it [00:45,  5.46s/it]
# Validation: 8it [00:47,  4.30s/it]
# Validation: 9it [00:48,  3.24s/it]
# Validation: 10it [00:49,  2.51s/it]
# Validation: 11it [00:50,  2.09s/it]
# Validation: 12it [00:51,  1.74s/it]
# Validation: 13it [01:00,  3.94s/it]
# Validation: 14it [01:02,  3.49s/it]
# Validation: 15it [01:03,  2.69s/it]
# Validation: 16it [01:04,  2.15s/it]
# Validation: 17it [01:05,  1.86s/it]
# Validation: 18it [01:06,  1.66s/it]
# Validation: 19it [01:14,  3.63s/it]
# Validation: 20it [01:17,  3.44s/it]
# Validation: 21it [01:18,  2.66s/it]
# Validation: 22it [01:19,  2.17s/it]
# Validation: 23it [01:20,  1.87s/it]
# Validation: 24it [01:22,  1.65s/it]
# Validation: 25it [01:28,  3.20s/it]
# Validation: 26it [01:32,  3.26s/it]
# Validation: 27it [01:32,  2.51s/it]
# Validation: 28it [01:33,  2.01s/it]
# Validation: 29it [01:34,  1.70s/it]
# Validation: 30it [01:35,  1.50s/it]
# Validation: 31it [01:43,  3.49s/it]
# Validation: 32it [01:46,  3.34s/it]
# Validation: 33it [01:47,  2.60s/it]
# Validation: 34it [01:48,  2.07s/it]
# Validation: 35it [01:49,  1.69s/it]
# Validation: 36it [01:50,  1.52s/it]
# Validation: 37it [01:58,  3.48s/it]
# Validation: 38it [02:01,  3.19s/it]
# Validation: 39it [02:02,  2.49s/it]
# Validation: 40it [02:02,  1.99s/it]
# Validation: 41it [02:03,  1.66s/it]
# Validation: 42it [02:04,  1.40s/it]
# Validation: 43it [02:10,  2.68s/it]
# Validation: 44it [02:11,  2.26s/it]
# Validation: 45it [02:11,  1.71s/it]
# Validation: 46it [02:12,  1.32s/it]
# Validation: 47it [02:12,  1.06s/it]
# Validation: 48it [02:13,  1.15it/s]
# Epoch 001: 168it [11:16,  2.10s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:38, 38.12s/it]
# Validation: 2it [00:38, 16.13s/it]
# Validation: 3it [00:39,  9.23s/it]
# Validation: 4it [00:40,  5.93s/it]
# Validation: 5it [00:41,  4.19s/it]
# Validation: 6it [00:42,  3.13s/it]
# Validation: 7it [00:57,  6.76s/it]
# Validation: 8it [00:58,  4.93s/it]
# Validation: 9it [00:59,  3.67s/it]
# Validation: 10it [00:59,  2.79s/it]
# Validation: 11it [01:00,  2.20s/it]
# Validation: 12it [01:01,  1.79s/it]
# Validation: 13it [01:12,  4.54s/it]
# Validation: 14it [01:13,  3.44s/it]
# Validation: 15it [01:14,  2.64s/it]
# Validation: 16it [01:15,  2.12s/it]
# Validation: 17it [01:15,  1.72s/it]
# Validation: 18it [01:16,  1.53s/it]
# Validation: 19it [01:26,  4.01s/it]
# Validation: 20it [01:27,  3.05s/it]
# Validation: 21it [01:28,  2.39s/it]
# Validation: 22it [01:29,  1.94s/it]
# Validation: 23it [01:30,  1.59s/it]
# Validation: 24it [01:30,  1.36s/it]
# Validation: 25it [01:40,  3.77s/it]
# Validation: 26it [01:41,  2.99s/it]
# Validation: 27it [01:42,  2.34s/it]
# Validation: 28it [01:43,  1.89s/it]
# Validation: 29it [01:43,  1.52s/it]
# Validation: 30it [01:44,  1.32s/it]
# Validation: 31it [01:55,  4.05s/it]
# Validation: 32it [01:55,  3.10s/it]
# Validation: 33it [01:56,  2.40s/it]
# Validation: 34it [01:57,  1.94s/it]
# Validation: 35it [01:58,  1.61s/it]
# Validation: 36it [01:59,  1.36s/it]
# Validation: 37it [02:09,  4.11s/it]
# Validation: 38it [02:10,  3.13s/it]
# Validation: 39it [02:11,  2.44s/it]
# Validation: 40it [02:12,  1.96s/it]
# Validation: 41it [02:13,  1.64s/it]
# Validation: 42it [02:13,  1.38s/it]
# Validation: 43it [02:20,  3.04s/it]
# Validation: 44it [02:21,  2.26s/it]
# Validation: 45it [02:21,  1.71s/it]
# Validation: 46it [02:22,  1.32s/it]
# Validation: 47it [02:22,  1.05s/it]
# Validation: 48it [02:22,  1.15it/s]
# Epoch 001: 232it [16:06,  2.30s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:29, 29.17s/it]
# Validation: 2it [00:30, 12.68s/it]
# Validation: 3it [00:31,  7.31s/it]
# Validation: 4it [00:32,  4.79s/it]
# Validation: 5it [00:33,  3.42s/it]
# Validation: 6it [00:33,  2.53s/it]
# Validation: 7it [00:45,  5.57s/it]
# Validation: 8it [00:46,  4.05s/it]
# Validation: 9it [00:47,  3.05s/it]
# Validation: 10it [00:48,  2.38s/it]
# Validation: 11it [00:49,  1.91s/it]
# Validation: 12it [00:49,  1.57s/it]
# Validation: 13it [01:00,  4.29s/it]
# Validation: 14it [01:01,  3.25s/it]
# Validation: 15it [01:02,  2.52s/it]
# Validation: 16it [01:03,  2.03s/it]
# Validation: 17it [01:03,  1.69s/it]
# Validation: 18it [01:04,  1.41s/it]
# Validation: 19it [01:15,  4.08s/it]
# Validation: 20it [01:15,  3.11s/it]
# Validation: 21it [01:16,  2.45s/it]
# Validation: 22it [01:17,  1.98s/it]
# Validation: 23it [01:18,  1.60s/it]
# Validation: 24it [01:19,  1.36s/it]
# Validation: 25it [01:29,  3.95s/it]
# Validation: 26it [01:30,  3.04s/it]
# Validation: 27it [01:30,  2.40s/it]
# Validation: 28it [01:31,  1.91s/it]
# Validation: 29it [01:32,  1.61s/it]
# Validation: 30it [01:33,  1.39s/it]
# Validation: 31it [01:43,  3.86s/it]
# Validation: 32it [01:44,  3.00s/it]
# Validation: 33it [01:44,  2.32s/it]
# Validation: 34it [01:45,  1.89s/it]
# Validation: 35it [01:46,  1.57s/it]
# Validation: 36it [01:47,  1.36s/it]
# Validation: 37it [01:56,  3.66s/it]
# Validation: 38it [01:59,  3.39s/it]
# Validation: 39it [01:59,  2.59s/it]
# Validation: 40it [02:00,  2.07s/it]
# Validation: 41it [02:01,  1.73s/it]
# Validation: 42it [02:02,  1.43s/it]
# Validation: 43it [02:06,  2.08s/it]
# Validation: 44it [02:08,  2.03s/it]
# Validation: 45it [02:08,  1.56s/it]
# Validation: 46it [02:08,  1.23s/it]
# Validation: 47it [02:09,  1.00it/s]
# Validation: 48it [02:09,  1.20it/s]
# Epoch 001: 296it [20:49,  2.47s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:37, 37.50s/it]
# Validation: 2it [00:38, 16.26s/it]
# Validation: 3it [00:40,  9.42s/it]
# Validation: 4it [00:41,  6.07s/it]
# Validation: 5it [00:42,  4.25s/it]
# Validation: 6it [00:43,  3.11s/it]
# Validation: 7it [00:56,  6.49s/it]
# Validation: 8it [00:57,  4.67s/it]
# Validation: 9it [00:58,  3.47s/it]
# Validation: 10it [00:58,  2.67s/it]
# Validation: 11it [00:59,  2.15s/it]
# Validation: 12it [01:01,  1.84s/it]
# Validation: 13it [01:11,  4.35s/it]
# Validation: 14it [01:12,  3.28s/it]
# Validation: 15it [01:12,  2.52s/it]
# Validation: 16it [01:13,  2.02s/it]
# Validation: 17it [01:14,  1.67s/it]
# Validation: 18it [01:15,  1.52s/it]
# Validation: 19it [01:25,  3.97s/it]
# Validation: 20it [01:26,  3.01s/it]
# Validation: 21it [01:26,  2.34s/it]
# Validation: 22it [01:27,  1.89s/it]
# Validation: 23it [01:28,  1.58s/it]
# Validation: 24it [01:29,  1.37s/it]
# Validation: 25it [01:39,  4.00s/it]
# Validation: 26it [01:40,  3.07s/it]
# Validation: 27it [01:41,  2.41s/it]
# Validation: 28it [01:42,  1.94s/it]
# Validation: 29it [01:43,  1.62s/it]
# Validation: 30it [01:43,  1.41s/it]
# Validation: 31it [01:54,  4.16s/it]
# Validation: 32it [01:55,  3.16s/it]
# Validation: 33it [01:56,  2.46s/it]
# Validation: 34it [01:56,  1.92s/it]
# Validation: 35it [01:57,  1.60s/it]
# Validation: 36it [01:58,  1.38s/it]
# Validation: 37it [02:08,  4.07s/it]
# Validation: 38it [02:09,  3.08s/it]
# Validation: 39it [02:10,  2.41s/it]
# Validation: 40it [02:11,  1.95s/it]
# Validation: 41it [02:12,  1.58s/it]
# Validation: 42it [02:13,  1.38s/it]
# Validation: 43it [02:20,  3.24s/it]
# Validation: 44it [02:21,  2.40s/it]
# Validation: 45it [02:21,  1.82s/it]
# Validation: 46it [02:21,  1.40s/it]
# Validation: 47it [02:22,  1.11s/it]
# Validation: 48it [02:22,  1.11it/s]
# Epoch 001: 360it [25:43,  2.09s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:29, 29.75s/it]
# Validation: 2it [00:30, 12.92s/it]
# Validation: 3it [00:31,  7.50s/it]
# Validation: 4it [00:32,  4.90s/it]
# Validation: 5it [00:33,  3.48s/it]
# Validation: 6it [00:34,  2.60s/it]
# Validation: 7it [00:46,  5.69s/it]
# Validation: 8it [00:47,  4.24s/it]
# Validation: 9it [00:49,  3.27s/it]
# Validation: 10it [00:50,  2.60s/it]
# Validation: 11it [00:50,  2.06s/it]
# Validation: 12it [00:51,  1.71s/it]
# Validation: 13it [01:03,  4.64s/it]
# Validation: 14it [01:04,  3.51s/it]
# Validation: 15it [01:05,  2.73s/it]
# Validation: 16it [01:05,  2.18s/it]
# Validation: 17it [01:06,  1.78s/it]
# Validation: 18it [01:07,  1.60s/it]
# Validation: 19it [01:18,  4.19s/it]
# Validation: 20it [01:19,  3.19s/it]
# Validation: 21it [01:19,  2.46s/it]
# Validation: 22it [01:20,  1.99s/it]
# Validation: 23it [01:21,  1.59s/it]
# Validation: 24it [01:22,  1.45s/it]
# Validation: 25it [01:32,  4.02s/it]
# Validation: 26it [01:33,  3.09s/it]
# Validation: 27it [01:34,  2.42s/it]
# Validation: 28it [01:35,  1.91s/it]
# Validation: 29it [01:35,  1.57s/it]
# Validation: 30it [01:36,  1.32s/it]
# Validation: 31it [01:47,  4.17s/it]
# Validation: 32it [01:48,  3.17s/it]
# Validation: 33it [01:49,  2.48s/it]
# Validation: 34it [01:49,  1.99s/it]
# Validation: 35it [01:50,  1.61s/it]
# Validation: 36it [01:51,  1.38s/it]
# Validation: 37it [02:02,  4.16s/it]
# Validation: 38it [02:02,  3.13s/it]
# Validation: 39it [02:03,  2.46s/it]
# Validation: 40it [02:04,  2.00s/it]
# Validation: 41it [02:05,  1.65s/it]
# Validation: 42it [02:06,  1.40s/it]
# Validation: 43it [02:12,  2.95s/it]
# Validation: 44it [02:13,  2.19s/it]
# Validation: 45it [02:13,  1.66s/it]
# Validation: 46it [02:14,  1.29s/it]
# Validation: 47it [02:14,  1.03s/it]
# Validation: 48it [02:15,  1.18it/s]
# Epoch 002:   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 002: 16it [00:51,  2.29s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:34, 34.07s/it]
# Validation: 2it [00:35, 14.97s/it]
# Validation: 3it [00:37,  8.74s/it]
# Validation: 4it [00:38,  5.87s/it]
# Validation: 5it [00:40,  4.32s/it]
# Validation: 6it [00:41,  3.43s/it]
# Validation: 7it [00:55,  6.80s/it]
# Validation: 8it [00:56,  4.96s/it]
# Validation: 9it [00:57,  3.68s/it]
# Validation: 10it [00:58,  2.82s/it]
# Validation: 11it [00:59,  2.22s/it]
# Validation: 12it [00:59,  1.81s/it]
# Validation: 13it [01:09,  4.04s/it]
# Validation: 14it [01:10,  3.35s/it]
# Validation: 15it [01:11,  2.61s/it]
# Validation: 16it [01:12,  2.08s/it]
# Validation: 17it [01:13,  1.70s/it]
# Validation: 18it [01:14,  1.43s/it]
# Validation: 19it [01:24,  4.09s/it]
# Validation: 20it [01:25,  3.13s/it]
# Validation: 21it [01:26,  2.43s/it]
# Validation: 22it [01:27,  1.94s/it]
# Validation: 23it [01:27,  1.61s/it]
# Validation: 24it [01:28,  1.38s/it]
# Validation: 25it [01:39,  4.06s/it]
# Validation: 26it [01:39,  3.08s/it]
# Validation: 27it [01:40,  2.45s/it]
# Validation: 28it [01:41,  1.95s/it]
# Validation: 29it [01:42,  1.64s/it]
# Validation: 30it [01:43,  1.42s/it]
# Validation: 31it [01:54,  4.25s/it]
# Validation: 32it [01:55,  3.23s/it]
# Validation: 33it [01:55,  2.50s/it]
# Validation: 34it [01:56,  2.01s/it]
# Validation: 35it [01:57,  1.67s/it]
# Validation: 36it [01:58,  1.44s/it]
# Validation: 37it [02:09,  4.14s/it]
# Validation: 38it [02:09,  3.13s/it]
# Validation: 39it [02:10,  2.44s/it]
# Validation: 40it [02:11,  1.98s/it]
# Validation: 41it [02:12,  1.64s/it]
# Validation: 42it [02:13,  1.41s/it]
# Validation: 43it [02:18,  2.48s/it]
# Validation: 44it [02:18,  1.87s/it]
# Validation: 45it [02:19,  1.46s/it]
# Validation: 46it [02:19,  1.16s/it]
# Validation: 47it [02:20,  1.05it/s]
# Validation: 48it [02:20,  1.24it/s]
# Epoch 002: 80it [05:40,  3.27s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:31, 31.73s/it]
# Validation: 2it [00:32, 13.73s/it]
# Validation: 3it [00:33,  7.94s/it]
# Validation: 4it [00:34,  5.22s/it]
# Validation: 5it [00:35,  3.69s/it]
# Validation: 6it [00:36,  2.79s/it]
# Validation: 7it [00:49,  5.82s/it]
# Validation: 8it [00:49,  4.26s/it]
# Validation: 9it [00:50,  3.22s/it]
# Validation: 10it [00:51,  2.46s/it]
# Validation: 11it [00:52,  1.98s/it]
# Validation: 12it [00:53,  1.65s/it]
# Validation: 13it [01:03,  4.15s/it]
# Validation: 14it [01:04,  3.14s/it]
# Validation: 15it [01:05,  2.46s/it]
# Validation: 16it [01:05,  1.97s/it]
# Validation: 17it [01:06,  1.64s/it]
# Validation: 18it [01:07,  1.41s/it]
# Validation: 19it [01:17,  3.86s/it]
# Validation: 20it [01:18,  3.02s/it]
# Validation: 21it [01:19,  2.35s/it]
# Validation: 22it [01:19,  1.87s/it]
# Validation: 23it [01:20,  1.56s/it]
# Validation: 24it [01:21,  1.34s/it]
# Validation: 25it [01:32,  4.34s/it]
# Validation: 26it [01:33,  3.39s/it]
# Validation: 27it [01:35,  2.74s/it]
# Validation: 28it [01:36,  2.29s/it]
# Validation: 29it [01:37,  1.96s/it]
# Validation: 30it [01:38,  1.74s/it]
# Validation: 31it [01:54,  6.05s/it]
# Validation: 32it [01:55,  4.46s/it]
# Validation: 33it [01:56,  3.36s/it]
# Validation: 34it [01:57,  2.59s/it]
# Validation: 35it [01:58,  2.07s/it]
# Validation: 36it [01:58,  1.70s/it]
# Validation: 37it [02:08,  4.15s/it]
# Validation: 38it [02:09,  3.16s/it]
# Validation: 39it [02:10,  2.47s/it]
# Validation: 40it [02:11,  1.98s/it]
# Validation: 41it [02:12,  1.68s/it]
# Validation: 42it [02:13,  1.46s/it]
# Validation: 43it [02:17,  2.27s/it]
# Validation: 44it [02:17,  1.73s/it]
# Validation: 45it [02:18,  1.35s/it]
# Validation: 46it [02:18,  1.08s/it]
# Validation: 47it [02:19,  1.12it/s]
# Validation: 48it [02:19,  1.30it/s]
# Epoch 002: 144it [10:26,  2.22s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:25, 25.72s/it]
# Validation: 2it [00:27, 11.49s/it]
# Validation: 3it [00:28,  6.86s/it]
# Validation: 4it [00:29,  4.61s/it]
# Validation: 5it [00:30,  3.31s/it]
# Validation: 6it [00:31,  2.48s/it]
# Validation: 7it [00:40,  4.58s/it]
# Validation: 8it [00:42,  3.70s/it]
# Validation: 9it [00:43,  2.89s/it]
# Validation: 10it [00:44,  2.34s/it]
# Validation: 11it [00:45,  1.88s/it]
# Validation: 12it [00:46,  1.54s/it]
# Validation: 13it [00:53,  3.43s/it]
# Validation: 14it [00:57,  3.36s/it]
# Validation: 15it [00:58,  2.67s/it]
# Validation: 16it [00:59,  2.13s/it]
# Validation: 17it [00:59,  1.74s/it]
# Validation: 18it [01:00,  1.51s/it]
# Validation: 19it [01:08,  3.37s/it]
# Validation: 20it [01:09,  2.63s/it]
# Validation: 21it [01:10,  2.19s/it]
# Validation: 22it [01:11,  1.87s/it]
# Validation: 23it [01:12,  1.54s/it]
# Validation: 24it [01:13,  1.40s/it]
# Validation: 25it [01:22,  3.59s/it]
# Validation: 26it [01:23,  2.86s/it]
# Validation: 27it [01:24,  2.26s/it]
# Validation: 28it [01:25,  1.87s/it]
# Validation: 29it [01:26,  1.63s/it]
# Validation: 30it [01:27,  1.49s/it]
# Validation: 31it [01:36,  3.67s/it]
# Validation: 32it [01:37,  2.94s/it]
# Validation: 33it [01:38,  2.35s/it]
# Validation: 34it [01:39,  1.90s/it]
# Validation: 35it [01:40,  1.57s/it]
# Validation: 36it [01:41,  1.44s/it]
# Validation: 37it [01:51,  4.05s/it]
# Validation: 38it [01:52,  3.11s/it]
# Validation: 39it [01:53,  2.42s/it]
# Validation: 40it [01:54,  1.96s/it]
# Validation: 41it [01:54,  1.61s/it]
# Validation: 42it [01:55,  1.41s/it]
# Validation: 43it [02:03,  3.36s/it]
# Validation: 44it [02:04,  2.51s/it]
# Validation: 45it [02:04,  1.92s/it]
# Validation: 46it [02:05,  1.48s/it]
# Validation: 47it [02:05,  1.16s/it]
# Validation: 48it [02:06,  1.06it/s]
# Epoch 002: 208it [15:07,  2.83s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:27, 27.47s/it]
# Validation: 2it [00:28, 12.06s/it]
# Validation: 3it [00:29,  7.04s/it]
# Validation: 4it [00:30,  4.68s/it]
# Validation: 5it [00:31,  3.36s/it]
# Validation: 6it [00:33,  2.64s/it]
# Validation: 7it [00:42,  4.96s/it]
# Validation: 8it [00:44,  4.01s/it]
# Validation: 9it [00:45,  2.99s/it]
# Validation: 10it [00:46,  2.32s/it]
# Validation: 11it [00:47,  1.88s/it]
# Validation: 12it [00:48,  1.66s/it]
# Validation: 13it [00:57,  3.87s/it]
# Validation: 14it [00:58,  2.97s/it]
# Validation: 15it [00:59,  2.35s/it]
# Validation: 16it [01:00,  1.90s/it]
# Validation: 17it [01:00,  1.59s/it]
# Validation: 18it [01:01,  1.38s/it]
# Validation: 19it [01:11,  3.95s/it]
# Validation: 20it [01:12,  3.01s/it]
# Validation: 21it [01:13,  2.35s/it]
# Validation: 22it [01:14,  1.87s/it]
# Validation: 23it [01:15,  1.58s/it]
# Validation: 24it [01:15,  1.36s/it]
# Validation: 25it [01:26,  4.07s/it]
# Validation: 26it [01:27,  3.12s/it]
# Validation: 27it [01:28,  2.53s/it]
# Validation: 28it [01:29,  1.99s/it]
# Validation: 29it [01:30,  1.66s/it]
# Validation: 30it [01:30,  1.44s/it]
# Validation: 31it [01:40,  3.83s/it]
# Validation: 32it [01:41,  2.90s/it]
# Validation: 33it [01:42,  2.32s/it]
# Validation: 34it [01:42,  1.88s/it]
# Validation: 35it [01:43,  1.58s/it]
# Validation: 36it [01:44,  1.38s/it]
# Validation: 37it [01:59,  5.52s/it]
# Validation: 38it [02:03,  5.03s/it]
# Validation: 39it [02:04,  3.88s/it]
# Validation: 40it [02:06,  3.09s/it]
# Validation: 41it [02:07,  2.47s/it]
# Validation: 42it [02:08,  1.98s/it]
# Validation: 43it [02:13,  3.15s/it]
# Validation: 44it [02:15,  2.73s/it]
# Validation: 45it [02:16,  2.04s/it]
# Validation: 46it [02:16,  1.55s/it]
# Validation: 47it [02:16,  1.22s/it]
# Validation: 48it [02:17,  1.02it/s]
# Epoch 002: 272it [19:53,  2.23s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:28, 28.05s/it]
# Validation: 2it [00:29, 12.17s/it]
# Validation: 3it [00:30,  7.05s/it]
# Validation: 4it [00:31,  4.68s/it]
# Validation: 5it [00:32,  3.31s/it]
# Validation: 6it [00:33,  2.54s/it]
# Validation: 7it [00:45,  5.63s/it]
# Validation: 8it [00:45,  4.03s/it]
# Validation: 9it [00:46,  3.04s/it]
# Validation: 10it [00:47,  2.38s/it]
# Validation: 11it [00:48,  1.92s/it]
# Validation: 12it [00:49,  1.67s/it]
# Validation: 13it [00:59,  4.27s/it]
# Validation: 14it [01:00,  3.25s/it]
# Validation: 15it [01:01,  2.55s/it]
# Validation: 16it [01:02,  2.04s/it]
# Validation: 17it [01:03,  1.68s/it]
# Validation: 18it [01:04,  1.52s/it]
# Validation: 19it [01:13,  3.94s/it]
# Validation: 20it [01:14,  3.01s/it]
# Validation: 21it [01:15,  2.37s/it]
# Validation: 22it [01:16,  1.91s/it]
# Validation: 23it [01:17,  1.58s/it]
# Validation: 24it [01:18,  1.34s/it]
# Validation: 25it [01:27,  3.81s/it]
# Validation: 26it [01:28,  2.91s/it]
# Validation: 27it [01:29,  2.30s/it]
# Validation: 28it [01:30,  1.85s/it]
# Validation: 29it [01:30,  1.53s/it]
# Validation: 30it [01:31,  1.31s/it]
# Validation: 31it [01:41,  3.85s/it]
# Validation: 32it [01:42,  2.95s/it]
# Validation: 33it [01:43,  2.31s/it]
# Validation: 34it [01:43,  1.88s/it]
# Validation: 35it [01:44,  1.59s/it]
# Validation: 36it [01:45,  1.34s/it]
# Validation: 37it [01:56,  4.14s/it]
# Validation: 38it [01:57,  3.17s/it]
# Validation: 39it [01:58,  2.49s/it]
# Validation: 40it [01:59,  2.01s/it]
# Validation: 41it [01:59,  1.65s/it]
# Validation: 42it [02:00,  1.41s/it]
# Validation: 43it [02:08,  3.24s/it]
# Validation: 44it [02:08,  2.40s/it]
# Validation: 45it [02:09,  1.81s/it]
# Validation: 46it [02:09,  1.39s/it]
# Validation: 47it [02:09,  1.11s/it]
# Validation: 48it [02:10,  1.09it/s]
# Epoch 002: 336it [24:32,  2.50s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:28, 28.31s/it]
# Validation: 2it [00:29, 12.44s/it]
# Validation: 3it [00:30,  7.22s/it]
# Validation: 4it [00:31,  4.73s/it]
# Validation: 5it [00:32,  3.37s/it]
# Validation: 6it [00:33,  2.58s/it]
# Validation: 7it [00:46,  5.87s/it]
# Validation: 8it [00:47,  4.27s/it]
# Validation: 9it [00:47,  3.21s/it]
# Validation: 10it [00:48,  2.45s/it]
# Validation: 11it [00:49,  1.94s/it]
# Validation: 12it [00:50,  1.62s/it]
# Validation: 13it [01:00,  4.18s/it]
# Validation: 14it [01:01,  3.21s/it]
# Validation: 15it [01:02,  2.54s/it]
# Validation: 16it [01:03,  1.98s/it]
# Validation: 17it [01:03,  1.63s/it]
# Validation: 18it [01:04,  1.38s/it]
# Validation: 19it [01:14,  3.97s/it]
# Validation: 20it [01:17,  3.50s/it]
# Validation: 21it [01:18,  2.73s/it]
# Validation: 22it [01:18,  2.13s/it]
# Validation: 23it [01:19,  1.77s/it]
# Validation: 24it [01:20,  1.46s/it]
# Validation: 25it [01:29,  3.69s/it]
# Validation: 26it [01:31,  3.34s/it]
# Validation: 27it [01:32,  2.67s/it]
# Validation: 28it [01:33,  2.11s/it]
# Validation: 29it [01:34,  1.74s/it]
# Validation: 30it [01:35,  1.44s/it]
# Validation: 31it [01:44,  3.60s/it]
# Validation: 32it [01:45,  2.97s/it]
# Validation: 33it [01:46,  2.40s/it]
# Validation: 34it [01:47,  1.99s/it]
# Validation: 35it [01:48,  1.65s/it]
# Validation: 36it [01:49,  1.40s/it]
# Validation: 37it [01:58,  3.85s/it]
# Validation: 38it [02:00,  3.31s/it]
# Validation: 39it [02:01,  2.63s/it]
# Validation: 40it [02:03,  2.20s/it]
# Validation: 41it [02:04,  1.90s/it]
# Validation: 42it [02:05,  1.71s/it]
# Validation: 43it [02:16,  4.51s/it]
# Validation: 44it [02:17,  3.34s/it]
# Validation: 45it [02:17,  2.48s/it]
# Validation: 46it [02:18,  1.87s/it]
# Validation: 47it [02:18,  1.46s/it]
# Validation: 48it [02:19,  1.16s/it]
# Epoch 002: 400it [29:18,  2.17s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:15, 15.15s/it]
# Validation: 2it [00:15,  6.72s/it]
# Validation: 3it [00:16,  4.09s/it]
# Validation: 4it [00:17,  2.82s/it]
# Validation: 5it [00:18,  2.12s/it]
# Validation: 6it [00:19,  1.78s/it]
# Validation: 7it [00:28,  4.04s/it]
# Validation: 8it [00:29,  3.04s/it]
# Validation: 9it [00:30,  2.37s/it]
# Validation: 10it [00:31,  1.89s/it]
# Validation: 11it [00:31,  1.58s/it]
# Validation: 12it [00:32,  1.36s/it]
# Validation: 13it [00:42,  3.99s/it]
# Validation: 14it [00:43,  3.05s/it]
# Validation: 15it [00:44,  2.36s/it]
# Validation: 16it [00:45,  1.90s/it]
# Validation: 17it [00:46,  1.57s/it]
# Validation: 18it [00:47,  1.37s/it]
# Validation: 19it [00:57,  3.98s/it]
# Validation: 20it [00:57,  3.04s/it]
# Validation: 21it [00:58,  2.37s/it]
# Validation: 22it [00:59,  1.93s/it]
# Validation: 23it [01:00,  1.60s/it]
# Validation: 24it [01:01,  1.38s/it]
# Validation: 25it [01:11,  3.99s/it]
# Validation: 26it [01:12,  3.05s/it]
# Validation: 27it [01:13,  2.39s/it]
# Validation: 28it [01:14,  1.93s/it]
# Validation: 29it [01:14,  1.62s/it]
# Validation: 30it [01:15,  1.36s/it]
# Validation: 31it [01:26,  4.13s/it]
# Validation: 32it [01:27,  3.16s/it]
# Validation: 33it [01:27,  2.46s/it]
# Validation: 34it [01:28,  1.97s/it]
# Validation: 35it [01:29,  1.63s/it]
# Validation: 36it [01:30,  1.39s/it]
# Validation: 37it [01:39,  3.81s/it]
# Validation: 38it [01:40,  2.90s/it]
# Validation: 39it [01:41,  2.27s/it]
# Validation: 40it [01:42,  1.83s/it]
# Validation: 41it [01:43,  1.54s/it]
# Validation: 42it [01:43,  1.32s/it]
# Validation: 43it [01:49,  2.50s/it]
# Validation: 44it [01:49,  1.93s/it]
# Validation: 45it [01:50,  1.50s/it]
# Validation: 46it [01:50,  1.18s/it]
# Validation: 47it [01:51,  1.04it/s]
# Validation: 48it [01:51,  1.21it/s]
# Epoch 003:   0%|          | 0/3 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 003: 56it [02:35,  2.67s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:24, 24.46s/it]
# Validation: 2it [00:25, 10.85s/it]
# Validation: 3it [00:26,  6.38s/it]
# Validation: 4it [00:27,  4.29s/it]
# Validation: 5it [00:28,  3.12s/it]
# Validation: 6it [00:29,  2.35s/it]
# Validation: 7it [00:39,  4.76s/it]
# Validation: 8it [00:40,  3.58s/it]
# Validation: 9it [00:41,  2.75s/it]
# Validation: 10it [00:42,  2.18s/it]
# Validation: 11it [00:43,  1.77s/it]
# Validation: 12it [00:44,  1.46s/it]
# Validation: 13it [00:52,  3.59s/it]
# Validation: 14it [00:55,  3.30s/it]
# Validation: 15it [00:56,  2.60s/it]
# Validation: 16it [00:57,  2.09s/it]
# Validation: 17it [00:57,  1.74s/it]
# Validation: 18it [00:58,  1.48s/it]
# Validation: 19it [01:05,  3.15s/it]
# Validation: 20it [01:10,  3.60s/it]
# Validation: 21it [01:11,  2.80s/it]
# Validation: 22it [01:12,  2.21s/it]
# Validation: 23it [01:13,  1.83s/it]
# Validation: 24it [01:14,  1.54s/it]
# Validation: 25it [01:19,  2.78s/it]
# Validation: 26it [01:23,  3.10s/it]
# Validation: 27it [01:24,  2.48s/it]
# Validation: 28it [01:25,  2.07s/it]
# Validation: 29it [01:26,  1.70s/it]
# Validation: 30it [01:27,  1.41s/it]
# Validation: 31it [01:34,  3.24s/it]
# Validation: 32it [01:37,  3.11s/it]
# Validation: 33it [01:38,  2.53s/it]
# Validation: 34it [01:39,  2.07s/it]
# Validation: 35it [01:41,  1.81s/it]
# Validation: 36it [01:41,  1.48s/it]
# Validation: 37it [01:48,  3.01s/it]
# Validation: 38it [01:51,  3.08s/it]
# Validation: 39it [01:52,  2.54s/it]
# Validation: 40it [01:54,  2.14s/it]
# Validation: 41it [01:55,  1.83s/it]
# Validation: 42it [01:56,  1.63s/it]
# Validation: 43it [02:01,  2.79s/it]
# Validation: 44it [02:03,  2.45s/it]
# Validation: 45it [02:03,  1.84s/it]
# Validation: 46it [02:04,  1.42s/it]
# Validation: 47it [02:04,  1.12s/it]
# Validation: 48it [02:05,  1.10it/s]
# Epoch 003: 120it [07:15,  2.45s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:28, 28.63s/it]
# Validation: 2it [00:30, 12.66s/it]
# Validation: 3it [00:31,  7.63s/it]
# Validation: 4it [00:32,  4.98s/it]
# Validation: 5it [00:34,  3.70s/it]
# Validation: 6it [00:35,  2.81s/it]
# Validation: 7it [00:49,  6.56s/it]
# Validation: 8it [00:50,  4.75s/it]
# Validation: 9it [00:51,  3.51s/it]
# Validation: 10it [00:52,  2.72s/it]
# Validation: 11it [00:52,  2.15s/it]
# Validation: 12it [00:54,  1.84s/it]
# Validation: 13it [01:04,  4.42s/it]
# Validation: 14it [01:05,  3.35s/it]
# Validation: 15it [01:06,  2.58s/it]
# Validation: 16it [01:06,  2.05s/it]
# Validation: 17it [01:07,  1.66s/it]
# Validation: 18it [01:08,  1.48s/it]
# Validation: 19it [01:19,  4.20s/it]
# Validation: 20it [01:20,  3.19s/it]
# Validation: 21it [01:20,  2.49s/it]
# Validation: 22it [01:21,  2.01s/it]
# Validation: 23it [01:22,  1.65s/it]
# Validation: 24it [01:23,  1.46s/it]
# Validation: 25it [01:33,  3.84s/it]
# Validation: 26it [01:33,  2.87s/it]
# Validation: 27it [01:34,  2.26s/it]
# Validation: 28it [01:35,  1.83s/it]
# Validation: 29it [01:36,  1.57s/it]
# Validation: 30it [01:37,  1.36s/it]
# Validation: 31it [01:47,  4.06s/it]
# Validation: 32it [01:48,  3.10s/it]
# Validation: 33it [01:49,  2.42s/it]
# Validation: 34it [01:50,  1.95s/it]
# Validation: 35it [01:50,  1.63s/it]
# Validation: 36it [01:51,  1.43s/it]
# Validation: 37it [02:01,  3.75s/it]
# Validation: 38it [02:01,  2.86s/it]
# Validation: 39it [02:02,  2.30s/it]
# Validation: 40it [02:03,  1.87s/it]
# Validation: 41it [02:04,  1.58s/it]
# Validation: 42it [02:05,  1.37s/it]
# Validation: 43it [02:11,  2.85s/it]
# Validation: 44it [02:12,  2.13s/it]
# Validation: 45it [02:12,  1.62s/it]
# Validation: 46it [02:13,  1.27s/it]
# Validation: 47it [02:13,  1.01s/it]
# Validation: 48it [02:14,  1.19it/s]
# Epoch 003: 184it [11:55,  2.39s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:30, 30.23s/it]
# Validation: 2it [00:31, 13.04s/it]
# Validation: 3it [00:32,  7.53s/it]
# Validation: 4it [00:33,  5.16s/it]
# Validation: 5it [00:35,  3.87s/it]
# Validation: 6it [00:36,  2.96s/it]
# Validation: 7it [00:50,  6.43s/it]
# Validation: 8it [00:51,  4.68s/it]
# Validation: 9it [00:51,  3.48s/it]
# Validation: 10it [00:52,  2.67s/it]
# Validation: 11it [00:53,  2.11s/it]
# Validation: 12it [00:54,  1.73s/it]
# Validation: 13it [01:04,  4.41s/it]
# Validation: 14it [01:05,  3.35s/it]
# Validation: 15it [01:06,  2.58s/it]
# Validation: 16it [01:07,  2.07s/it]
# Validation: 17it [01:08,  1.69s/it]
# Validation: 18it [01:09,  1.45s/it]
# Validation: 19it [01:18,  3.85s/it]
# Validation: 20it [01:19,  2.94s/it]
# Validation: 21it [01:20,  2.33s/it]
# Validation: 22it [01:21,  1.88s/it]
# Validation: 23it [01:22,  1.54s/it]
# Validation: 24it [01:22,  1.33s/it]
# Validation: 25it [01:33,  4.01s/it]
# Validation: 26it [01:34,  3.07s/it]
# Validation: 27it [01:34,  2.42s/it]
# Validation: 28it [01:35,  1.97s/it]
# Validation: 29it [01:36,  1.66s/it]
# Validation: 30it [01:37,  1.41s/it]
# Validation: 31it [01:47,  3.99s/it]
# Validation: 32it [01:48,  3.04s/it]
# Validation: 33it [01:49,  2.39s/it]
# Validation: 34it [01:50,  1.93s/it]
# Validation: 35it [01:51,  1.63s/it]
# Validation: 36it [01:51,  1.37s/it]
# Validation: 37it [02:01,  3.74s/it]
# Validation: 38it [02:02,  2.90s/it]
# Validation: 39it [02:02,  2.28s/it]
# Validation: 40it [02:03,  1.86s/it]
# Validation: 41it [02:04,  1.58s/it]
# Validation: 42it [02:05,  1.36s/it]
# Validation: 43it [02:11,  2.86s/it]
# Validation: 44it [02:12,  2.14s/it]
# Validation: 45it [02:12,  1.63s/it]
# Validation: 46it [02:13,  1.28s/it]
# Validation: 47it [02:13,  1.03s/it]
# Validation: 48it [02:14,  1.17it/s]
# Epoch 003: 248it [16:41,  2.35s/it]
# Validation: 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Validation: 1it [00:28, 28.73s/it]
# Validation: 2it [00:29, 12.55s/it]
# Validation: 3it [00:31,  7.37s/it]
# Validation: 4it [00:32,  4.87s/it]
# Validation: 5it [00:33,  3.58s/it]
# Validation: 6it [00:34,  2.77s/it]
# Validation: 7it [00:47,  6.13s/it]
# Validation: 8it [00:49,  4.82s/it]
# Validation: 9it [00:50,  3.59s/it]
# Validation: 10it [00:51,  2.77s/it]
# Validation: 11it [00:52,  2.17s/it]
# Validation: 12it [00:53,  1.75s/it]
# Validation: 13it [01:02,  4.05s/it]
# Validation: 14it [01:04,  3.56s/it]
# Validation: 15it [01:05,  2.73s/it]
# Validation: 16it [01:06,  2.17s/it]
# Validation: 17it [01:07,  1.73s/it]
# Validation: 18it [01:08,  1.49s/it]
# Validation: 19it [01:16,  3.56s/it]
# Validation: 20it [01:19,  3.27s/it]
# Validation: 21it [01:20,  2.56s/it]
# Validation: 22it [01:21,  2.06s/it]
# Validation: 23it [01:21,  1.68s/it]
# Validation: 24it [01:22,  1.43s/it]
# Validation: 25it [01:31,  3.57s/it]
# Validation: 26it [01:34,  3.38s/it]
# Validation: 27it [01:34,  2.60s/it]
# Validation: 28it [01:35,  2.11s/it]
# Validation: 29it [01:36,  1.75s/it]
# Validation: 30it [01:37,  1.53s/it]
# Validation: 31it [01:45,  3.47s/it]
# Validation: 32it [01:49,  3.61s/it]
# Validation: 33it [01:50,  2.77s/it]
# Validation: 34it [01:51,  2.20s/it]
# Validation: 35it [01:52,  1.80s/it]
# Validation: 36it [01:53,  1.50s/it]
# Validation: 37it [01:59,  2.95s/it]
# Validation: 38it [02:04,  3.52s/it]
# Validation: 39it [02:05,  2.72s/it]
# Validation: 40it [02:05,  2.14s/it]
# Validation: 41it [02:06,  1.75s/it]
# Validation: 42it [02:07,  1.46s/it]
# Validation: 43it [02:09,  1.52s/it]
# Validation: 44it [02:11,  1.69s/it]
# Validation: 45it [02:11,  1.32s/it]
# Validation: 46it [02:12,  1.06s/it]
# Validation: 47it [02:12,  1.14it/s]
# Validation: 48it [02:13,  1.35it/s]
# Epoch 003: 276it [19:51,  1.92s/it]
# Maximum number of iterations reached
# Completed

# %%
from google.colab import drive
import shutil

# upload the log and model to google drive
drive.mount('/content/drive')

source_folder = "/content/CS599-Fake-Video-Detection/logs"
target_folder = "/content/drive/MyDrive/CS599/runs"

shutil.copytree(source_folder, target_folder)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/CS599/runs'

# %%
source_folder = "/content/CS599-Fake-Video-Detection/weights"
target_folder = "/content/drive/MyDrive/CS599/weights"

shutil.copytree(source_folder, target_folder)
# Out:
# '/content/drive/MyDrive/CS599/weights'
